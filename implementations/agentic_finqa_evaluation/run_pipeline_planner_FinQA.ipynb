# %% [markdown]
# ### Configuration

# %%
import sys
import uuid
from pathlib import Path

# %%
# ── Tune these before running ────────────────────────────────────────────────
N_SAMPLES = 5  # samples to process (keep ≤10 for a first run)
CONFIG = "gemini_gemini"  # gemini_gemini | openai_openai | openai_gemini | gemini_openai
SPLIT = "test"
USE_OCR = False  # False = skip OcrReaderTool  (--no_ocr equivalent)
USE_VERIFIER = True  # False = skip VerifierAgent  (--no_verifier equivalent)
OCR_MODEL = None  # None = same model as vision; 'gemini-2.5-flash-lite' = cheaper OCR
USE_JUDGE = True  # True = LLM rubric judge (extra API calls per sample)
RUN_ABLATION = True  # True = also run without OCR after the main run
# ────────────────────────────────────────────────────────────────────

REPO_ROOT = Path(".").resolve()
RUN_ID = str(uuid.uuid4())
OUT_DIR = str(REPO_ROOT / "meps" / CONFIG / "chartqapro" / SPLIT)
IMAGE_DIR = str(REPO_ROOT / "data" / "chartqapro_images")
OUT_LABEL = f"{CONFIG}_n{N_SAMPLES}"

ocr_status = "enabled" if USE_OCR else "disabled"
ver_status = "enabled" if USE_VERIFIER else "disabled"
print(f"Config     : {CONFIG}")
print(f"Samples    : {N_SAMPLES}  split={SPLIT}")
print(f"OCR        : {ocr_status}")
print(f"Verifier   : {ver_status}")
print(f"LLM judge  : {'enabled' if USE_JUDGE else 'disabled (--no_judge)'}")
print(f"Run ID     : {RUN_ID}")
print(f"Output dir : {OUT_DIR}")
# Out:
# Config     : gemini_gemini
# Samples    : 5  split=test
# OCR        : disabled
# Verifier   : enabled
# LLM judge  : enabled
# Run ID     : bf63e4f7-c847-4b02-9a0e-d348e23bf290
# Output dir : /home/coder/interpretability-llms-agents/implementations/agentic_finqa_evaluation/meps/gemini_gemini/chartqapro/test

# %% [markdown]
# ### Environment

# %%
import json
import os

# %%
# Make sure src/ is on the path
src_path = str(REPO_ROOT / "src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

from dotenv import load_dotenv  # noqa: E402
load_dotenv(REPO_ROOT / ".env")
# API key check
missing = []
for var, needed_for in [("OPENAI_API_KEY", "openai"), ("GEMINI_API_KEY", "gemini")]:
    val = os.environ.get(var, "")
    needed = needed_for in CONFIG
    if val and not val.startswith("your_"):
        print(f"  ok  {var}  ({val[:3]}...)")
    elif needed:
        print(f"  MISSING  {var}  <- required for {CONFIG}")
        missing.append(var)
    else:
        print(f"  skip  {var}  (not needed for {CONFIG})")
if missing:
    raise EnvironmentError(f"Set {missing} in .env and re-run this cell.")
# Out:
#   ok  OPENAI_API_KEY  (AIz...)
#   ok  GEMINI_API_KEY  (AIz...)

# %%
# Imports
import pandas as pd  # noqa: E402
from agentic_finqa_eval.agents.planner_agent_finqa import PlannerAgent  # noqa: E402
from agentic_finqa_eval.agents.verifier_agent_finqa import VerifierAgent  # noqa: E402
from agentic_finqa_eval.agents.analyst_agent_finqa import AnalystAgent  # noqa: E402
from agentic_finqa_eval.datasets.finqa_loader import load_finqa # noqa: E402
# from agentic_finqa_eval.eval.error_taxonomy import classify_failure  # noqa: E402
from agentic_finqa_eval.eval.eval_outputs_finqa import evaluate_mep  # noqa: E402
# from agentic_finqa_eval.eval.eval_topk import evaluate_topk  # noqa: E402
# from agentic_finqa_eval.eval.eval_traces import evaluate_trace  # noqa: E402
# from agentic_finqa_eval.eval.summarize import summarize, write_csv  # noqa: E402
from agentic_finqa_eval.langfuse_integration.client import get_client  # noqa: E402
from agentic_finqa_eval.mep.writer import iter_meps  # noqa: E402
from agentic_finqa_eval.runner.run_generate_meps_finqa import (  # noqa: E402
    BACKEND_CONFIGS,
    process_sample,
)
# from agentic_finqa_eval.tools.ocr_reader_tool import OcrReaderTool  # noqa: E402
# from IPython.display import Image, display  # noqa: E402, A004
print("\nAll imports OK")
# Out:
# All imports OK

# %% [markdown]
# ### Langfuse Health Check
#
# Verifies that Langfuse credentials are configured before the pipeline runs.
# | Check | What it tests |
# |---|---|
# | Env vars present | `LANGFUSE_PUBLIC_KEY` and `LANGFUSE_SECRET_KEY` are set in `.env` |
# | Client init | `Langfuse()` initialises without error |
# If the keys are absent the cell prints a skip notice and continues — Langfuse is optional.
# The pipeline produces identical MEPs with or without it; tracing is purely additive.

# %%
from agentic_finqa_eval.langfuse_integration.client import reset_client


# Force re-initialisation so re-running this cell picks up any .env changes
reset_client()

lf_public = os.environ.get("LANGFUSE_PUBLIC_KEY", "")
lf_secret = os.environ.get("LANGFUSE_SECRET_KEY", "")

if not lf_public or not lf_secret:
    print("[skip] LANGFUSE_PUBLIC_KEY / LANGFUSE_SECRET_KEY are not set.")
    print("       Langfuse tracing is disabled. Pipeline will run fine without it.")
    print()
    print("To enable Langfuse tracing, add to .env:")
    print("  LANGFUSE_PUBLIC_KEY=pk-lf-...")
    print("  LANGFUSE_SECRET_KEY=sk-lf-...")
    print("  # LANGFUSE_HOST=https://cloud.langfuse.com  (default; change for self-hosted)")
else:
    results = {}

    # -- Check 1: Env vars present --
    results["env"] = ("ok", f"pk={lf_public[:3]}...")

    # -- Check 2: Client initialises --
    try:
        _lf_hc = get_client()
        if _lf_hc is not None:
            results["client"] = ("ok", "Langfuse() ready")
        else:
            results["client"] = ("fail", "get_client() returned None")
    except Exception as e:
        results["client"] = ("fail", str(e))

    # -- Report --
    labels = [
        ("env", "Env vars present"),
        ("client", "Client init     "),
    ]
    all_ok = True
    for key, label in labels:
        status, detail = results.get(key, ("skip", ""))
        marker = "✓ OK  " if status == "ok" else ("⊘ skip" if status == "skip" else "✗ FAIL")
        if status not in ("ok", "skip"):
            all_ok = False
        print(f"  {marker}  {label}  {detail}")

    print()
    if all_ok:
        lf_host = os.environ.get("LANGFUSE_HOST") or os.environ.get("LANGFUSE_BASE_URL") or "https://cloud.langfuse.com"
        print("✓ Langfuse is configured.")
        print(f"Host      : {lf_host}")
        print("Traces and scores will be recorded automatically during the pipeline run.")
    else:
        print("⚠ WARNING: Langfuse client failed to initialise.")
        print("The pipeline will still run; tracing will be skipped.")
# Out:
#   ✓ OK    Env vars present  pk=pk-...
#   ✓ OK    Client init       Langfuse() ready
#
# ✓ Langfuse is configured.
# Host      : https://us.cloud.langfuse.com
# Traces and scores will be recorded automatically during the pipeline run.

# %% [markdown]
# ### Load Dataset

# %%
samples = load_finqa(n=N_SAMPLES, finqa_dir= "FinQA_dataset", finqa_filename= "dev_updated_with_answer.json")

# %% [markdown]
# ### Instantiate Planner Agent, Analyst Agent and verifier

# %%
config = dict(BACKEND_CONFIGS[CONFIG])
Path(OUT_DIR).mkdir(parents=True, exist_ok=True)

# PlannerAgent: text-only LLM, no image access
planner = PlannerAgent(
    backend=config["planner_backend"],
    model=config["planner_model"],
)
print(f"PlannerAgent   : {config['planner_backend']} / {config['planner_model']}")

# AnalystAgent: multimodal LLM + VisionQATool
analyst_agent = AnalystAgent(
    agent_backend=config["analyst_backend"],
    agent_model=config["analyst_model"])
print(f"AnalystAgent   : {config['analyst_backend']} / {config['analyst_model']}")

# VerifierAgent: optional Pass 2.5 critic
verifier = None
if USE_VERIFIER:
    verifier = VerifierAgent(backend=config["analyst_backend"], model=config["analyst_model"])
    print(f"VerifierAgent  : {config['analyst_backend']} / {config['analyst_model']}")
else:
    print("VerifierAgent  : disabled (USE_VERIFIER=False)")

# # OcrReaderTool: optional perception pre-pass
# ocr = None
# if USE_OCR:
#     ocr_model = OCR_MODEL or config["vision_model"]
#     ocr = OcrReaderTool(backend=config["vision_backend"], model=ocr_model)
#     print(f"OcrReaderTool  : {config['vision_backend']} / {ocr_model}")
# else:
#     print("OcrReaderTool  : disabled (USE_OCR=False)")

# Langfuse observability (no-op if keys not set)
lf_client = get_client()
lf_status = "enabled" if lf_client else "not configured"
print(f"Langfuse       : {lf_status}")
# Out:
# PlannerAgent   : gemini / gemini-2.5-flash
# AnalystAgent   : gemini / gemini-2.5-flash
# VerifierAgent  : gemini / gemini-2.5-flash
# Langfuse       : enabled

# %% [markdown]
# ## 5 — Run the Pipeline
#
# For each sample: **Plan → [OCR] → Vision → [Verify] → write MEP**.
#
# Each call to `process_sample()` is fully self-contained: it creates a fresh CrewAI `Crew`,
# runs the agent chain, and serialises the result to `OUT_DIR/<sample_id>.json`.
#
# To parallelise, increase `N_WORKERS` below and run again.

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed


N_WORKERS = 1  # set >1 to parallelise (increase N_SAMPLES too)

mep_paths = []
print(f"Running {len(samples)} samples  workers={N_WORKERS}  -> {OUT_DIR}\n")


def _run_one(sample):
    return process_sample(
        sample,
        planner,
        analyst_agent,
        config,
        RUN_ID,
        OUT_DIR,
        lf_client=lf_client,
        verifier_agent=verifier,
    )


if N_WORKERS <= 1:
    for i, sample in enumerate(samples, 1):
        print(f"[{i}/{len(samples)}] {sample['id']} ...", end=" ", flush=True)
        try:
            path = _run_one(sample)
            mep_paths.append(path)
            print("OK")
        except Exception as exc:
            print(f"ERROR: {exc}")
else:
    with ThreadPoolExecutor(max_workers=N_WORKERS) as pool:
        futures = {pool.submit(_run_one, s): s for s in samples}
        for done, fut in enumerate(as_completed(futures), 1):
            
            s = futures[fut]
            try:
                path = fut.result()
                mep_paths.append(path)
                print(f"[{done}/{len(samples)}] {s['id']} -> OK")
            except Exception as exc:
                print(f"[{done}/{len(samples)}] {s['id']} ERROR: {exc}")

print(f"\nDone -- {len(mep_paths)}/{len(samples)} MEPs written to {OUT_DIR}")
# Out:
# Running 5 samples  workers=1  -> /home/coder/interpretability-llms-agents/implementations/agentic_finqa_evaluation/meps/gemini_gemini/chartqapro/test
#
# [1/5] V/2008/page_17.pdf-1 ... OK
# [2/5] C/2017/page_328.pdf-1 ... Maximum iterations reached. Requesting final answer.
# OK
# [3/5] DVN/2007/page_58.pdf-2 ... OK
# [4/5] ETR/2011/page_341.pdf-3 ... OK
# [5/5] ETR/2004/page_213.pdf-2 ... OK
#
# Done -- 5/5 MEPs written to /home/coder/interpretability-llms-agents/implementations/agentic_finqa_evaluation/meps/gemini_gemini/chartqapro/test

# %% [markdown]
# ## 6 — Inspect First MEP
#
# MEPs are self-contained JSON files. Every field you see here is what the agent actually
# produced — no post-processing. The `lf_trace_id` links this MEP back to the live trace
# in the Langfuse dashboard if Langfuse is configured.

# %%
if not mep_paths:
    print("No MEPs written -- check errors above.")
else:
    mep = json.loads(Path(sorted(mep_paths)[0]).read_text())
    s = mep["sample"]
    pl = mep.get("plan", {}).get("parsed", {})
    vi = mep.get("analyst", {}).get("parsed", {})
    vr = (mep.get("verifier") or {}).get("parsed", {})
    ts = mep.get("timestamps", {})
    tr = mep.get("analyst", {}).get("tool_trace", {})[0]
    meda = tr.get("provider_metadata", {})

    print("=" * 64)
    print(f"Sample   : {s['sample_id']}")
    print(f"Pre-text   : {s['pre_text']}")
    print(f"Table   : {s['table']}")
    print(f"Post-text   : {s['post_text']}")
    # print(f"Type     : {s['question_type']}")
    print(f"Question : {s['question']}")
    print(f"Expected : {s['expected_answer']}")
    print()
    print("Planner steps:")
    for j, step in enumerate(pl.get("steps", []), 1):
        print(f"  {j}. {step}")
    print()
    print(f"Analyst answer : {vi.get('answer', '--')}")
    print(f"Explanation   : {vi.get('explanation', '--')[:280]}")
    if vr:
        print()
        print(f"Verifier verdict  : {vr.get('verdict', '--')}")
        print(f"Verifier answer   : {vr.get('answer', '--')}")
        print(f"Verifier reasoning: {vr.get('reasoning', '--')}")
    print()
    print("Tool usage:")
    print(f"  {'Tool':<16} {tr["tool"]}")
    for t in ["a", "b", "math_ops", "result"]:
        print(f"  {t:<16} {meda.get(t, 0)}")
    print()
    print("Timestamps (ms):")
    for k in ["planner_ms", "ocr_ms", "vision_ms", "verifier_ms"]:
        print(f"  {k:<16} {ts.get(k, 0):.0f}")
    if mep.get("lf_trace_id"):
        print(f"Langfuse trace ID: {mep['lf_trace_id']}")
    print("=" * 64)

    # img_path = s.get("image_ref", {}).get("path", "")
    # if img_path and Path(img_path).exists():
    #     display(Image(filename=img_path, width=640))
    # else:
    #     print(f"(image not found at: {img_path})")
# Out:
# ================================================================
# Sample   : C/2017/page_328.pdf-1
# Pre-text   : ['performance graph comparison of five-year cumulative total return the following graph and table compare the cumulative total return on citi 2019s common stock , which is listed on the nyse under the ticker symbol 201cc 201d and held by 65691 common stockholders of record as of january 31 , 2018 , with the cumulative total return of the s&p 500 index and the s&p financial index over the five-year period through december 31 , 2017 .', 'the graph and table assume that $ 100 was invested on december 31 , 2012 in citi 2019s common stock , the s&p 500 index and the s&p financial index , and that all dividends were reinvested .', 'comparison of five-year cumulative total return for the years ended date citi s&p 500 financials .']
# Table   : [['date', 'citi', 's&p 500', 's&p financials'], ['31-dec-2012', '100.0', '100.0', '100.0'], ['31-dec-2013', '131.8', '132.4', '135.6'], ['31-dec-2014', '137.0', '150.5', '156.2'], ['31-dec-2015', '131.4', '152.6', '153.9'], ['31-dec-2016', '152.3', '170.8', '188.9'], ['31-dec-2017', '193.5', '208.1', '230.9']]
# Post-text   : ['.']
# Question : what was the percentage cumulative total return for the five year period ended 31-dec-2017 of citi common stock?
# Expected :
#
# Planner steps:
#   1. Identify the cumulative total return for 'citi' on '31-dec-2012' from the table.
#   2. Identify the cumulative total return for 'citi' on '31-dec-2017' from the table.
#   3. Subtract the 31-dec-2012 value from the 31-dec-2017 value to find the cumulative total return.
#   4. Express the result as a percentage.
#
# Analyst answer : 93.5%
# Explanation   : According to the table, the cumulative total return for Citi common stock on 31-dec-2012 was 100.0 and on 31-dec-2017 was 193.5. The cumulative total return is calculated by subtracting the 31-dec-2012 value from the 31-dec-2017 value (193.5 - 100.0 = 93.5). Since the initial inv
#
# Verifier verdict  : confirmed
# Verifier answer   : 93.5%
# Verifier reasoning: The analyst agent correctly identified the values from the table and calculated the cumulative total return by subtracting the initial investment value from the final value, expressing it as a percentage, which aligns with the provided data and inspection plan.
#
# Tool usage:
#   Tool             math_ops_tool
#   a                193.5
#   b                100.0
#   math_ops         subtraction
#   result           93.5
#
# Timestamps (ms):
#   planner_ms       5422
#   ocr_ms           0
#   vision_ms        0
#   verifier_ms      3985
# Langfuse trace ID: c96892e2cacf721603cd173c5ff9d66f
# ================================================================

# %% [markdown]
# ## 7 — OCR Insight: What Was Injected into the Vision Prompt?
#
# The OcrReaderTool makes a single VLM call focused purely on text transcription.
# Its structured JSON output is injected into the VisionAgent's prompt as `{ocr_block}`.
#
# This cell shows exactly what was transcribed and injected. When `USE_OCR=False`,
# `{ocr_block}` renders as an empty string and the prompt is otherwise unchanged —
# a clean example of conditional context injection without prompt branching.

# %%
# if not mep_paths:
#     print("No MEPs to inspect.")
# else:
#     mep = json.loads(Path(sorted(mep_paths)[0]).read_text())
#     ocr_data = mep.get("ocr")

#     if ocr_data is None:
#         print("OCR was disabled (ocr: null in MEP).")
#         print("The {ocr_block} placeholder in vision.txt rendered as an empty string.")
#         print("Re-run with USE_OCR=True to see OCR output.")
#     else:
#         parsed = ocr_data.get("parsed", {})
#         ts = mep.get("timestamps", {})
#         print(f"OCR elapsed     : {ts.get('ocr_ms', 0):.0f} ms")
#         print(f"Parse error     : {ocr_data.get('parse_error', False)}")
#         print()
#         print("Structured OCR output (injected as {ocr_block} into vision.txt):")
#         print(f"  chart_type  : {parsed.get('chart_type', '--')}")
#         print(f"  title       : {parsed.get('title', '--')}")
#         x = parsed.get("x_axis", {})
#         print(f"  x_axis      : label={x.get('label', '--')}  ticks={x.get('ticks', [])}")
#         y = parsed.get("y_axis", {})
#         print(f"  y_axis      : label={y.get('label', '--')}  ticks={y.get('ticks', [])}")
#         print(f"  legend      : {parsed.get('legend', [])}")
#         print(f"  data_labels : {parsed.get('data_labels', [])}")
#         print(f"  annotations : {parsed.get('annotations', [])}")
#         print()
#         # Show raw OCR text
#         raw = ocr_data.get("raw_text", "")
#         print("Raw OCR response (first 400 chars):")
#         print(raw[:400])

# %% [markdown]
# ## 8 — Ablation: Run Without OCR
#
# Runs the same samples with `ocr_tool=None` and writes to a separate directory.
# This lets you compare the two runs side-by-side in Pass 1 evaluation.
#
# Set `RUN_ABLATION=False` in the config cell to skip this section.

# %%
# no_ocr_paths = []
# OUT_DIR_NO_OCR = str(REPO_ROOT / "meps" / (CONFIG + "_no_ocr") / "chartqapro" / SPLIT)
# RUN_ID_NO_OCR = str(uuid.uuid4())

# if not RUN_ABLATION:
#     print("Skipped (RUN_ABLATION=False).")
# elif not USE_OCR:
#     print("USE_OCR is already False -- the main run above IS the no-OCR baseline.")
#     print("Set USE_OCR=True and re-run to get the with-OCR version for comparison.")
# else:
#     Path(OUT_DIR_NO_OCR).mkdir(parents=True, exist_ok=True)
#     print(f"Running {len(samples)} samples WITHOUT OCR -> {OUT_DIR_NO_OCR}\n")
#     for i, sample in enumerate(samples, 1):
#         print(f"[{i}/{len(samples)}] {sample.sample_id} ...", end=" ", flush=True)
#         try:
#             path = process_sample(
#                 sample,
#                 planner,
#                 vision_agent,
#                 config,
#                 RUN_ID_NO_OCR,
#                 OUT_DIR_NO_OCR,
#                 lf_client=lf_client,
#                 verifier_agent=verifier,
#                 ocr_tool=None,  # <-- OCR disabled
#             )
#             no_ocr_paths.append(path)
#             print("OK")
#         except Exception as exc:
#             print(f"ERROR: {exc}")
#     print(f"\nDone -- {len(no_ocr_paths)} no-OCR MEPs written")
#     print("\nOCR vs no-OCR: check ocr_ms in timestamps for the time cost:")
#     if mep_paths:
#         mep_with = json.loads(Path(sorted(mep_paths)[0]).read_text())
#         mep_without = json.loads(Path(no_ocr_paths[0]).read_text())
#         print(
#             f"  With OCR    ocr_ms={mep_with.get('timestamps', {}).get('ocr_ms', 0):.0f}  vision_ms={mep_with.get('timestamps', {}).get('vision_ms', 0):.0f}"
#         )
#         print(
#             f"  Without OCR ocr_ms={mep_without.get('timestamps', {}).get('ocr_ms', 0):.0f}  vision_ms={mep_without.get('timestamps', {}).get('vision_ms', 0):.0f}"
#         )

# %% [markdown]
# ## 9 — Pass 1: Evaluate Outputs
#
# Rule-based accuracy scoring + optional LLM judge (5 rubric dimensions).
#
# - `answer_accuracy`: exact-match with numeric tolerance; MCQ partial credit
# - `verifier_verdict`: `confirmed` / `revised` / `skipped`
# - `judge_*`: scored 0–1 by a text LLM (only when `USE_JUDGE=True`)
#
# Results are written to `metrics_<label>.jsonl` in the repo root.

# %%
metrics_path = str(REPO_ROOT / "output" / f"metrics_{OUT_LABEL}.jsonl")
Path(REPO_ROOT / "output").mkdir(parents=True, exist_ok=True)
metrics_list = []

print(f"Evaluating MEPs in {OUT_DIR} ...")
with open(metrics_path, "w") as f_out:
    for mep_dict in iter_meps(OUT_DIR):
        try:
            m = evaluate_mep(
                mep_dict,
                use_judge=USE_JUDGE,
                judge_backend=config.get("judge_backend", "gemini"),
                judge_model=config.get("analyst_model", "gemini-2.5-flash"),
            )
            print(m)
            f_out.write(json.dumps(m) + "\n")
            metrics_list.append(m)
        except Exception as exc:
            print(f"  eval error: {exc}")

print(f"Pass 1 complete -- {len(metrics_list)} rows -> {metrics_path}\n")

df = pd.DataFrame(metrics_list)
print(f"Overall accuracy : {df['answer_accuracy'].mean():.1%}  (n={len(df)})")
if "verifier_verdict" in df.columns and not df["verifier_verdict"].eq("skipped").all():
    revised = (df["verifier_verdict"] == "revised").sum()
    print(f"Verifier revised : {revised}/{len(df)} ({revised / len(df):.1%})")

# Accuracy by question type
print()
print("Accuracy by question type:")
for qt, grp in df.groupby("question_type"):
    print(f"  {qt:<22} {grp['answer_accuracy'].mean():.1%}  (n={len(grp)})")
# Out:
# Evaluating MEPs in /home/coder/interpretability-llms-agents/implementations/agentic_finqa_evaluation/meps/gemini_gemini/chartqapro/test ...
# {'sample_id': 'AAPL/2004/page_36.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '0.2%', 'analyst_answer': '0.2%', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 6.339847564697266, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific, grounded in the assumed financial data, fully covers and adheres to the calculation plan, and logically supports the given answer."}
# {'sample_id': 'ABMD/2006/page_75.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '332', 'analyst_answer': '332', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 5.494493007659912, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific, grounded in the assumed provided financial data, fully covers the calculation plan, adheres to its steps, and logically supports the given answer."}
# {'sample_id': 'AMAT/2013/page_18.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': 'UNANSWERABLE', 'analyst_answer': 'UNANSWERABLE', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 8.340446472167969, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation thoroughly details the search for 'net sales' and '2018' across all document sections, precisely identifying what data is present and, crucially, what is missing, thereby fully supporting the 'UNANSWERABLE' conclusion and adhering perfectly to the provided plan."}
# {'sample_id': 'AOS/2004/page_11.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '34.01%', 'analyst_answer': '34.01%', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 7.926270246505737, 'tool_call_count': 2, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The explanation clearly identifies the values, performs the correct calculation, and logically supports the agent's answer, while fully adhering to the provided calculation plan."}
# {'sample_id': 'C/2010/page_223.pdf-3', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '', 'analyst_answer': '', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': False, 'json_parse_ok': False, 'answer_accuracy': 1.0, 'latency_sec': 7.457305908203125, 'tool_call_count': 3, 'has_errors': False, 'judge_explanation_quality': 0.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 0.0, 'judge_plan_adherence': 0.0, 'judge_faithfulness_alignment': 0.0, 'judge_reasoning': "The 'Expected Answer', 'Agent Answer', and 'Agent Explanation' fields are empty, preventing any evaluation of the agent's performance or explanation."}
# {'sample_id': 'C/2017/page_328.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '93.5%', 'analyst_answer': '93.5%', 'verifier_verdict': 'confirmed', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 16.206755876541138, 'tool_call_count': 3, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific, grounded in the presumed data, and accurately follows the provided calculation plan to logically support the given answer."}
# {'sample_id': 'CME/2017/page_97.pdf-5', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '995', 'analyst_answer': '995', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 6.631171226501465, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': 'The agent correctly identified the relevant values, performed the accurate calculation as per the plan, and provided a clear, specific, and grounded explanation that fully supports the answer.'}
# {'sample_id': 'DVN/2007/page_58.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '24.69%', 'analyst_answer': '24.79%', 'verifier_verdict': 'revised', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 10.410143375396729, 'tool_call_count': 2, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 0.0, 'judge_reasoning': 'The agent correctly identified the input values and followed the calculation steps, but made an arithmetic error in the final calculation (60 / 243 * 100 is 24.69%, not 24.79%), which means the explanation does not logically support the given answer despite appearing to align with it.'}
# {'sample_id': 'ETR/2004/page_213.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '60.31%', 'analyst_answer': 'UNANSWERABLE', 'verifier_verdict': 'revised', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 14.35841155052185, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 0.0, 'judge_hallucination_rate': 1.0, 'judge_plan_coverage': 0.0, 'judge_plan_adherence': 0.0, 'judge_faithfulness_alignment': 0.0, 'judge_reasoning': "The agent hallucinates by claiming 'the plan's instruction overrides its direct use for calculation' when the plan explicitly instructs to identify the value from the pre-text. The agent also internally contradicts itself by stating the value is 'mentioned in the pre-text' but then concluding it's 'not explicitly provided' and cannot be used, leading to poor quality, adherence, and alignment."}
# {'sample_id': 'ETR/2011/page_341.pdf-3', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '18.6', 'analyst_answer': '18.6', 'verifier_verdict': 'confirmed', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 13.032424926757812, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific, grounded in the assumed financial data, covers all steps of the calculation plan in order, and logically supports the given answer."}
# {'sample_id': 'JPM/2008/page_85.pdf-3', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': 'UNANSWERABLE', 'analyst_answer': 'UNANSWERABLE', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 8.117560625076294, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 0.5, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific, grounded, and covers all aspects of the calculation plan, logically supporting the 'UNANSWERABLE' conclusion. However, the steps were not followed in the exact order specified by the plan."}
# {'sample_id': 'LMT/2013/page_74.pdf-4', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '-1.9', 'analyst_answer': '-1.9', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 5.171327829360962, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': 'The agent provided a specific, data-grounded explanation covering all calculation steps, adhered to the plan, and the explanation faithfully aligned with the given answer without any hallucination.'}
# {'sample_id': 'MRO/2007/page_149.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '2057', 'analyst_answer': '2057', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 7.719676733016968, 'tool_call_count': 2, 'has_errors': False, 'judge_explanation_quality': 0.0, 'judge_hallucination_rate': 1.0, 'judge_plan_coverage': 0.0, 'judge_plan_adherence': 0.0, 'judge_faithfulness_alignment': 0.0, 'judge_reasoning': 'The agent provided a numerical answer and explanation for a question where the expected answer was empty, likely due to hallucinating the base data (1654 and 1251 million) which were not provided in the problem statement or implied as available.'}
# {'sample_id': 'MSI/2006/page_61.pdf-3', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '35.1%', 'analyst_answer': '35.1%', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 7.27141809463501, 'tool_call_count': 2, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation correctly identifies the relevant figures, performs the calculation as specified, and accurately derives the final answer, fully adhering to the provided plan."}
# {'sample_id': 'PKG/2009/page_65.pdf-4', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '56.202%', 'analyst_answer': '56.202%', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 11.070921897888184, 'tool_call_count': 2, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is specific and grounded in the presented data (assuming it's from an unseen table), it covers all required calculation steps, follows the plan's order, and its calculation correctly supports the given answer."}
# {'sample_id': 'PM/2017/page_38.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '688', 'analyst_answer': '688', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 7.80350661277771, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 0.1, 'judge_hallucination_rate': 0.9, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation strictly follows the provided (but flawed) plan and supports its answer, but its claim that a value in a generically titled column ('for the years ended december 31 , $') represents a multi-year change is a severe misinterpretation of financial data, leading to low explanation quality and high hallucination."}
# {'sample_id': 'PNC/2013/page_207.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': 'UNANSWERABLE', 'analyst_answer': 'UNANSWERABLE', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 11.036224603652954, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The Agent's explanation precisely follows the provided calculation plan, identifying the requested year, noting the available data's year, and concluding that the question is unanswerable due to missing data for 2014. The explanation is specific, grounded in the described data state, covers all plan steps, adheres to their order, and logically supports the UNANSWERABLE answer."}
# {'sample_id': 'PNC/2013/page_62.pdf-2', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': 'The total residential mortgages balance was $1356 million for 2013 and $2220 million for 2012.', 'analyst_answer': 'The total residential mortgages balance was $1356 million for 2013 and $2220 million for 2012.', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 5.528213024139404, 'tool_call_count': 0, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 0.75, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': 'The explanation is specific and faithfully supports the answer by detailing the data extraction from the specified table and rows, though it implicitly rather than explicitly addresses the initial understanding step of the ideal plan.'}
# {'sample_id': 'STT/2011/page_83.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '$114 million', 'analyst_answer': '$114 million', 'verifier_verdict': 'skipped', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 8.976703405380249, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 1.0, 'judge_hallucination_rate': 0.0, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 1.0, 'judge_reasoning': "The agent's explanation is precise, accurately uses the data provided in the question itself, follows all steps of the calculation plan, and logically supports the correct answer."}
# {'sample_id': 'V/2008/page_17.pdf-1', 'question_type': 'standard', 'config_name': 'gemini_gemini', 'expected': '', 'predicted': '127.4', 'analyst_answer': '127.4', 'verifier_verdict': 'confirmed', 'planner_parse_ok': True, 'analyst_parse_ok': True, 'json_parse_ok': True, 'answer_accuracy': 0.0, 'latency_sec': 22.13371992111206, 'tool_call_count': 1, 'has_errors': False, 'judge_explanation_quality': 0.3, 'judge_hallucination_rate': 0.5, 'judge_plan_coverage': 1.0, 'judge_plan_adherence': 1.0, 'judge_faithfulness_alignment': 0.3, 'judge_reasoning': "The agent correctly performs the numerical calculation but makes a significant error in the unit of the final answer, incorrectly stating it as 'billion' instead of an implied base unit like 'dollars per transaction', which diminishes explanation quality, represents a factual hallucination regarding the unit, and makes the explanation's conclusion unfaithful to a correct interpretation of the numerical answer."}
# Pass 1 complete -- 20 rows -> /home/coder/interpretability-llms-agents/implementations/agentic_finqa_evaluation/output/metrics_gemini_gemini_n5.jsonl
#
# Overall accuracy : 5.0%  (n=20)
# Verifier revised : 2/20 (10.0%)
#
# Accuracy by question type:
#   standard               5.0%  (n=20)

# %%
df
# Out:
#                   sample_id question_type    config_name expected  \
# 0   AAPL/2004/page_36.pdf-2      standard  gemini_gemini
# 1   ABMD/2006/page_75.pdf-1      standard  gemini_gemini
# 2   AMAT/2013/page_18.pdf-2      standard  gemini_gemini
# 3    AOS/2004/page_11.pdf-2      standard  gemini_gemini
# 4     C/2010/page_223.pdf-3      standard  gemini_gemini
# 5     C/2017/page_328.pdf-1      standard  gemini_gemini
# 6    CME/2017/page_97.pdf-5      standard  gemini_gemini
# 7    DVN/2007/page_58.pdf-2      standard  gemini_gemini
# 8   ETR/2004/page_213.pdf-2      standard  gemini_gemini
# 9   ETR/2011/page_341.pdf-3      standard  gemini_gemini
# 10   JPM/2008/page_85.pdf-3      standard  gemini_gemini
# 11   LMT/2013/page_74.pdf-4      standard  gemini_gemini
# 12  MRO/2007/page_149.pdf-2      standard  gemini_gemini
# 13   MSI/2006/page_61.pdf-3      standard  gemini_gemini
# 14   PKG/2009/page_65.pdf-4      standard  gemini_gemini
# 15    PM/2017/page_38.pdf-1      standard  gemini_gemini
# 16  PNC/2013/page_207.pdf-1      standard  gemini_gemini
# 17   PNC/2013/page_62.pdf-2      standard  gemini_gemini
# 18   STT/2011/page_83.pdf-1      standard  gemini_gemini
# 19     V/2008/page_17.pdf-1      standard  gemini_gemini
#
#                                             predicted  \
# 0                                                0.2%
# 1                                                 332
# 2                                        UNANSWERABLE
# 3                                              34.01%
# 4
# 5                                               93.5%
# 6                                                 995
# 7                                              24.69%
# 8                                              60.31%
# 9                                                18.6
# 10                                       UNANSWERABLE
# 11                                               -1.9
# 12                                               2057
# 13                                              35.1%
# 14                                            56.202%
# 15                                                688
# 16                                       UNANSWERABLE
# 17  The total residential mortgages balance was $1...
# 18                                       $114 million
# 19                                              127.4
#
#                                        analyst_answer verifier_verdict  \
# 0                                                0.2%          skipped
# 1                                                 332          skipped
# 2                                        UNANSWERABLE          skipped
# 3                                              34.01%          skipped
# 4                                                              skipped
# 5                                               93.5%        confirmed
# 6                                                 995          skipped
# 7                                              24.79%          revised
# 8                                        UNANSWERABLE          revised
# 9                                                18.6        confirmed
# 10                                       UNANSWERABLE          skipped
# 11                                               -1.9          skipped
# 12                                               2057          skipped
# 13                                              35.1%          skipped
# 14                                            56.202%          skipped
# 15                                                688          skipped
# 16                                       UNANSWERABLE          skipped
# 17  The total residential mortgages balance was $1...          skipped
# 18                                       $114 million          skipped
# 19                                              127.4        confirmed
#
#     planner_parse_ok  analyst_parse_ok  json_parse_ok  answer_accuracy  \
# 0               True              True           True              0.0
# 1               True              True           True              0.0
# 2               True              True           True              0.0
# 3               True              True           True              0.0
# 4               True             False          False              1.0
# 5               True              True           True              0.0
# 6               True              True           True              0.0
# 7               True              True           True              0.0
# 8               True              True           True              0.0
# 9               True              True           True              0.0
# 10              True              True           True              0.0
# 11              True              True           True              0.0
# 12              True              True           True              0.0
# 13              True              True           True              0.0
# 14              True              True           True              0.0
# 15              True              True           True              0.0
# 16              True              True           True              0.0
# 17              True              True           True              0.0
# 18              True              True           True              0.0
# 19              True              True           True              0.0
#
#     latency_sec  tool_call_count  has_errors  judge_explanation_quality  \
# 0      6.339848                1       False                        1.0
# 1      5.494493                1       False                        1.0
# 2      8.340446                0       False                        1.0
# 3      7.926270                2       False                        1.0
# 4      7.457306                3       False                        0.0
# 5     16.206756                3       False                        1.0
# 6      6.631171                1       False                        1.0
# 7     10.410143                2       False                        1.0
# 8     14.358412                0       False                        0.0
# 9     13.032425                1       False                        1.0
# 10     8.117561                0       False                        1.0
# 11     5.171328                1       False                        1.0
# 12     7.719677                2       False                        0.0
# 13     7.271418                2       False                        1.0
# 14    11.070922                2       False                        1.0
# 15     7.803507                0       False                        0.1
# 16    11.036225                0       False                        1.0
# 17     5.528213                0       False                        1.0
# 18     8.976703                1       False                        1.0
# 19    22.133720                1       False                        0.3
#
#     judge_hallucination_rate  judge_plan_coverage  judge_plan_adherence  \
# 0                        0.0                 1.00                   1.0
# 1                        0.0                 1.00                   1.0
# 2                        0.0                 1.00                   1.0
# 3                        0.0                 1.00                   1.0
# 4                        0.0                 0.00                   0.0
# 5                        0.0                 1.00                   1.0
# 6                        0.0                 1.00                   1.0
# 7                        0.0                 1.00                   1.0
# 8                        1.0                 0.00                   0.0
# 9                        0.0                 1.00                   1.0
# 10                       0.0                 1.00                   0.5
# 11                       0.0                 1.00                   1.0
# 12                       1.0                 0.00                   0.0
# 13                       0.0                 1.00                   1.0
# 14                       0.0                 1.00                   1.0
# 15                       0.9                 1.00                   1.0
# 16                       0.0                 1.00                   1.0
# 17                       0.0                 0.75                   1.0
# 18                       0.0                 1.00                   1.0
# 19                       0.5                 1.00                   1.0
#
#     judge_faithfulness_alignment  \
# 0                            1.0
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            0.0
# 5                            1.0
# 6                            1.0
# 7                            0.0
# 8                            0.0
# 9                            1.0
# 10                           1.0
# 11                           1.0
# 12                           0.0
# 13                           1.0
# 14                           1.0
# 15                           1.0
# 16                           1.0
# 17                           1.0
# 18                           1.0
# 19                           0.3
#
#                                       judge_reasoning
# 0   The agent's explanation is specific, grounded ...
# 1   The agent's explanation is specific, grounded ...
# 2   The agent's explanation thoroughly details the...
# 3   The explanation clearly identifies the values,...
# 4   The 'Expected Answer', 'Agent Answer', and 'Ag...
# 5   The agent's explanation is specific, grounded ...
# 6   The agent correctly identified the relevant va...
# 7   The agent correctly identified the input value...
# 8   The agent hallucinates by claiming 'the plan's...
# 9   The agent's explanation is specific, grounded ...
# 10  The agent's explanation is specific, grounded,...
# 11  The agent provided a specific, data-grounded e...
# 12  The agent provided a numerical answer and expl...
# 13  The agent's explanation correctly identifies t...
# 14  The agent's explanation is specific and ground...
# 15  The agent's explanation strictly follows the p...
# 16  The Agent's explanation precisely follows the ...
# 17  The explanation is specific and faithfully sup...
# 18  The agent's explanation is precise, accurately...
# 19  The agent correctly performs the numerical cal...

# %%
# Compare OCR vs no-OCR accuracy (only runs if ablation was done)
if no_ocr_paths:
    no_ocr_metrics = []
    for mep_dict in iter_meps(OUT_DIR_NO_OCR):
        import contextlib

        with contextlib.suppress(Exception):
            no_ocr_metrics.append(evaluate_mep(mep_dict, use_judge=False))
    df_no_ocr = pd.DataFrame(no_ocr_metrics)
    print("Accuracy comparison:")
    print(f"  WITH OCR    : {df['answer_accuracy'].mean():.1%}  (n={len(df)})")
    print(f"  WITHOUT OCR : {df_no_ocr['answer_accuracy'].mean():.1%}  (n={len(df_no_ocr)})")
    delta = df["answer_accuracy"].mean() - df_no_ocr["answer_accuracy"].mean()
    print(f"  Delta       : {delta:+.1%}  (positive = OCR helped)")
else:
    print("Ablation not run -- set RUN_ABLATION=True and re-run to compare OCR vs no-OCR.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Compare OCR vs no-OCR accuracy (only runs if ablation was done)
# ----> 2 if no_ocr_paths:
#       3     no_ocr_metrics = []
#       4     for mep_dict in iter_meps(OUT_DIR_NO_OCR):
#
# NameError: name 'no_ocr_paths' is not defined

# %% [markdown]
# ## 10 — Pass 2: Evaluate Traces
#
# Trace-level metrics: latency per agent, tool call counts, and replayability score
# (fraction of required MEP fields that are present and non-empty).

# %%
trace_path = str(REPO_ROOT / "output" / f"trace_metrics_{OUT_LABEL}.jsonl")
Path(REPO_ROOT / "output").mkdir(parents=True, exist_ok=True)
trace_rows = []

with open(trace_path, "w") as f_out:
    for mep_dict in iter_meps(OUT_DIR):
        row = evaluate_trace(mep_dict)
        f_out.write(json.dumps(row) + "\n")
        trace_rows.append(row)

trace_df = pd.DataFrame(trace_rows)
print(f"Pass 2 complete -- {len(trace_df)} rows -> {trace_path}\n")

cols = [
    "latency_sec",
    "planner_latency_sec",
    "vision_latency_sec",
    "tool_call_count",
    "replayability",
    "error_count",
]
cols = [c for c in cols if c in trace_df.columns]
print(trace_df[cols].describe().round(3).to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       5 with open(trace_path, "w") as f_out:
#       6     for mep_dict in iter_meps(OUT_DIR):
# ----> 7         row = evaluate_trace(mep_dict)
#       8         f_out.write(json.dumps(row) + "\n")
#       9         trace_rows.append(row)
#
# NameError: name 'evaluate_trace' is not defined

# %% [markdown]
# ## 11 — Pass 4: Failure Taxonomy
#
# For each **wrong** answer, a VLM is shown the chart image, the wrong answer,
# the correct answer, and the agent's explanation — and classifies the primary failure mode.
#
# Unlike a text-only judge, this pass can verify whether axis labels were actually ambiguous,
# whether the cited data point appears in the image, etc.
#
# Correct answers (`answer_accuracy == 1.0`) are skipped without making any API call.

# %%
taxonomy_path = str(REPO_ROOT / "output" / f"taxonomy_{OUT_LABEL}.jsonl")
Path(REPO_ROOT / "output").mkdir(parents=True, exist_ok=True)
taxonomy_rows = []

# Build accuracy lookup from Pass 1
acc_map = {r["sample_id"]: r["answer_accuracy"] for r in metrics_list}

vlm_backend = config["vision_backend"]
vlm_model = config["vision_model"]

print(f"Classifying failures using {vlm_backend} / {vlm_model} ...")
with open(taxonomy_path, "w") as f_out:
    for mep_dict in iter_meps(OUT_DIR):
        sid = mep_dict.get("sample", {}).get("sample_id", "")
        acc = acc_map.get(sid, 0.0)
        try:
            result = classify_failure(
                mep_dict,
                answer_accuracy=acc,
                backend=vlm_backend,
                model=vlm_model,
            )
            row = {"sample_id": sid, "answer_accuracy": acc, **result}
            f_out.write(json.dumps(row) + "\n")
            taxonomy_rows.append(row)
            marker = "(skipped -- correct)" if acc == 1.0 else result.get("failure_type", "")
            print(f"  {sid}: {marker}")
        except Exception as exc:
            print(f"  {sid}: ERROR {exc}")

tax_df = pd.DataFrame(taxonomy_rows)
print(f"\nPass 4 complete -- {len(tax_df)} rows -> {taxonomy_path}\n")
print("Failure type breakdown:")
print(tax_df["failure_type"].value_counts().to_string())

# %% [markdown]
# ## 12 — Top-K Evaluation (hit@1 / hit@2 / hit@3)
#
# Re-queries the VLM for each MEP asking for the top-K most likely candidate answers.
# Computes hit@k: whether the expected answer appears within the top-k candidates.
#
# - **hit@1** ≈ standard accuracy with a fresh independent call
# - **hit@2/3** measures how often the right answer is in the model's top candidates

# %%
topk_path = str(REPO_ROOT / "output" / f"topk_{OUT_LABEL}.jsonl")
Path(REPO_ROOT / "output").mkdir(parents=True, exist_ok=True)
topk_list = []

K = 3
topk_backend = config.get("vision_backend", "gemini")
topk_model = config.get("vision_model", "gemini-2.5-flash-lite")

print(f"Running top-{K} evaluation on MEPs in {OUT_DIR} ...")
print(f"  backend={topk_backend}  model={topk_model}\n")

with open(topk_path, "w") as f_out:
    for mep_dict in iter_meps(OUT_DIR):
        try:
            result = evaluate_topk(
                mep_dict,
                k=K,
                backend=topk_backend,
                model=topk_model,
            )
            f_out.write(json.dumps(result) + "\n")
            topk_list.append(result)
            sid = result["sample_id"]
            cands = result["topk_candidates"]
            h1 = result.get("hit_at_1", 0)
            hk = result.get(f"hit_at_{K}", 0)
            print(f"  {sid}  candidates={cands}  hit@1={h1:.0f}  hit@{K}={hk:.0f}")
        except Exception as exc:
            print(f"  eval error: {exc}")

print(f"\nTop-{K} complete -- {len(topk_list)} rows -> {topk_path}\n")

if topk_list:
    orig_acc = sum(r["original_accuracy"] for r in topk_list) / len(topk_list)
    print(f"Original accuracy (from MEP)  : {orig_acc:.1%}")
    for ki in range(1, K + 1):
        key = f"hit_at_{ki}"
        val = sum(r.get(key, 0) for r in topk_list) / len(topk_list)
        print(f"hit@{ki}                         : {val:.1%}")

# %% [markdown]
# ## 13 — Summarize
#
# Aggregate all metrics into `summary_<label>.csv`, grouped by `config_name` and `question_type`.
# To compare multiple configs, run cells 5–12 again with a different `CONFIG` value
# then concatenate the `metrics_*.jsonl` files before summarising.

# %%
summary_path = str(REPO_ROOT / "output" / f"summary_{OUT_LABEL}.csv")
Path(REPO_ROOT / "output").mkdir(parents=True, exist_ok=True)

rows = summarize(metrics_list)
write_csv(rows, summary_path)
print(f"Summary written -> {summary_path}  ({len(rows)} rows)\n")

summary_df = pd.DataFrame(rows)
rename = {
    "answer_accuracy_mean": "accuracy",
    "latency_sec_mean": "latency_s",
    "tool_call_count_mean": "tool_calls",
}
show_cols = [
    "config_name",
    "question_type",
    "count",
    "accuracy",
    "latency_s",
    "tool_calls",
]
show_cols = [c for c in show_cols if c in [rename.get(k, k) for k in summary_df.columns] + list(summary_df.columns)]

display(
    summary_df.rename(columns=rename)[
        [
            c
            for c in [
                "config_name",
                "question_type",
                "count",
                "accuracy",
                "latency_s",
                "tool_calls",
            ]
            if c in summary_df.rename(columns=rename).columns
        ]
    ]
    .fillna("")
    .style.format({"accuracy": "{:.1%}", "latency_s": "{:.1f}", "tool_calls": "{:.1f}"})
)

# %% [markdown]
# ## What to Explore Next
#
# - **`analysis.ipynb`** — visualise the results you just generated: accuracy charts, verifier
#   revision analysis, failure taxonomy bar chart, judge score distributions, per-sample browser
#
# - **Compare configs** — change `CONFIG` in Cell 1 to `gemini_gemini` or `openai_gemini`,
#   re-run cells 5–12, then concatenate the two `metrics_*.jsonl` files and summarise together
#
# - **Model overrides** — set `OCR_MODEL = 'gpt-4o-mini'` to run a cheaper model for OCR
#   while keeping `gpt-4o` for the VisionAgent
#
# - **Streamlit dashboard** — `streamlit run src/agentic_chartqapro_eval/eval/dashboard.py`
#
# - **HTML report** — `uv run --env-file .env -m agentic_chartqapro_eval.eval.report --metrics metrics_<label>.jsonl --taxonomy taxonomy_<label>.jsonl --out report.html`
